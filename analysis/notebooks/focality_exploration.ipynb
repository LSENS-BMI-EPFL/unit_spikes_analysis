# %%
import numpy as np
import os
import pandas as pd

# %%
# Load significant fraction

# %%
# Compute fractions for both groups
r_plus_fracs = r_plus_data.groupby('area')['significant'].mean().sort_values(ascending=False)
r_minus_fracs = r_minus_data.groupby('area')['significant'].mean().sort_values(ascending=False)

# Compare
comparison = pd.DataFrame({
    'R+': r_plus_fracs,
    'R-': r_minus_fracs,
    'Difference': r_plus_fracs - r_minus_fracs
}).sort_values('Difference', ascending=False)

print(comparison)
